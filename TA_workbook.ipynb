# %%
from technical_functions import MultipleTA, TA
import pandas as pd
import numpy as np
from importlib import reload

# %%
import read_in_data_functions


reload(read_in_data_functions)
from read_in_data_functions import get_sub_sectors_tickers

# %%
tech_tickers = get_sub_sectors_tickers('Technology', n = 30)

# %%
tickers = ['SAP', 'MSFT', 'PANW', 'IBM', 'MRVL', 'NXPI', 'CRDO', 'ASX', 'NVDA', 'AMD', 'MU']

# %%
semi_analysis = MultipleTA(tickers)

# %%
semi_analysis.plot_bullish_trends()
# Out:
# (<Figure size 1300x600 with 1 Axes>,
#  <Axes: title={'center': 'Bullish Overlaps (shading = number of tickers bullish)'}>)

# %%
panw = TA('TER')
panw.plot_price_chart()
# Out:
# Call TER.calc_zscore_and_rets() to get returns data
# Request URL: https://api.polygon.io/v2/aggs/ticker/TER/range/1/day/2023-10-12/2025-10-09?limit=5000
# Request Headers: {'Authorization': 'Bearer REDACTED', 'Accept-Encoding': 'gzip', 'User-Agent': 'Polygon.io PythonClient/1.15.3'}
# Response Headers: {'Date': 'Fri, 10 Oct 2025 18:26:00 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'X-Polygon-Cluster-Name': 'polygon-ny5', 'X-Request-Id': 'f5fc4d7115465a98fd47545e582e4dfa', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains'}
# Ratios successful
# Failed to get earning dates because of : 'earnings_date'
# (<Figure size 1200x700 with 2 Axes>,
#  array([<Axes: title={'center': 'TER • Price / BB / SMA / EMA (Full)'}>,
#         <Axes: title={'center': 'Volume'}>], dtype=object))

# %%
semi_analysis.plot_dynamic_conditional_correlation('NVDA')
# Out:
# (<Figure size 1200x400 with 1 Axes>,
#  <Axes: title={'center': 'Dynamic Conditional Correlation: NVDA vs SPX\n on close data'}>)
